# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import random
from tensorflow.keras import layers, Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import random
from tensorflow.keras import layers, Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %%
train_dir = "C:\\Users\\user\\Desktop\\cry\\content\\test_train-original\\train"
val_dir = "C:\\Users\\user\\Desktop\\cry\\content\\test_train-original\\val"
test_dir = "C:\\Users\\user\\Desktop\\cry\\content\\test_train-original\\test"

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
                                                          # featurewise_center=True,
                                                          # featurewise_std_normalization=True,
#                                                           rotation_range=90,
#                                                           width_shift_range=0.2,
#                                                           height_shift_range=0.2,
#                                                           horizontal_flip=True,
#                                                           zoom_range=0.2,
                                                          )

# %%
train_gen = datagen.flow_from_directory(train_dir,
                                                 target_size = (224,224),
                                                 batch_size = 32,
                                        shuffle=True,
                                                 class_mode = 'categorical')
test_gen= datagen.flow_from_directory(test_dir,
                                            target_size = (224,224),
                                            batch_size = 32,
                                      shuffle=False,
                                            class_mode ='categorical')
val_gen = datagen.flow_from_directory(val_dir,
                                            target_size = (224,224),
                                            batch_size = 32,
                                      shuffle=True,
                                          class_mode = 'categorical')
# Out:
# Found 4077 images belonging to 20 classes.
# Found 526 images belonging to 20 classes.
# Found 502 images belonging to 20 classes.

# %%
# Visualizing data
import os 
def visualize_random_images(dataset_type="train", label_type="Downy mildew(120)"):
    
    sample = 9
    
    plt.figure(figsize=(15, 8))
    type_dir = train_dir if dataset_type=="train" else test_dir
    base_dir = os.path.join(type_dir, label_type)
    images = random.sample(os.listdir(base_dir), 9)
    
    for i, image in enumerate(images):
        plt.subplot(3, 3, i+1)
        img = plt.imread(os.path.join(base_dir, image))
        plt.imshow(img)

# %%
visualize_random_images("/content/test_train-original/train/Downy mildew(120)/downymildew.  (10).jpg")

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
from keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential,load_model,save_model
from tensorflow.keras.layers import Dense,Conv2D,Flatten,MaxPooling2D

# %%
model=Sequential()


model.add(Conv2D(32, (3, 3) ,activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(2, padding='same'))


model.add(Conv2D(64, (3, 3) ,activation='relu', padding='same'))
model.add(MaxPooling2D(2, padding='same'))
model.add(BatchNormalization())


model.add(Conv2D(128, (3, 3) ,activation='relu', padding='same'))
model.add(MaxPooling2D(2, padding='same'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3) ,activation='relu', padding='same'))
model.add(MaxPooling2D(2, padding='same'))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3) ,activation='relu', padding='same'))
model.add(MaxPooling2D(2, padding='same'))
model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(1024 , activation='relu'))
model.add(layers.Dropout(.2))
model.add(Dense(1024, activation='relu'))


model.add(Dense(20, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 111, 111, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 56, 56, 64)       256
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 14, 14, 256)      1024
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 512)       1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 7, 7, 512)        2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 20)                20500
#
# =================================================================
# Total params: 28,333,652
# Trainable params: 28,331,732
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
# base_model = tf.keras.applications.EfficientNetB3(include_top=False)
# base_model.trainable = False

# for layer in base_model.layers[:-5]:
#   layer.trainable = False

# inputs = layers.Input(shape=(224, 224, 3), name="input_layer")
# base_layer = base_model(inputs)

# flat_layer = layers.Flatten()(base_layer)

# outputs = layers.Dense(20, activation="softmax")(flat_layer)
# model = Model(inputs, outputs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = model.fit(train_gen,
                       epochs=40,
                       validation_data=val_gen)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/40
# 128/128 [==============================] - 215s 2s/step - loss: 3.8426 - accuracy: 0.2674 - val_loss: 3.8584 - val_accuracy: 0.1753
# Epoch 2/40
# 128/128 [==============================] - 219s 2s/step - loss: 1.8020 - accuracy: 0.4479 - val_loss: 2.4926 - val_accuracy: 0.3845
# Epoch 3/40
# 128/128 [==============================] - 205s 2s/step - loss: 1.3887 - accuracy: 0.5747 - val_loss: 2.0774 - val_accuracy: 0.4841
# Epoch 4/40
# 128/128 [==============================] - 202s 2s/step - loss: 1.1176 - accuracy: 0.6412 - val_loss: 6.6392 - val_accuracy: 0.1375
# Epoch 5/40
# 128/128 [==============================] - 204s 2s/step - loss: 0.8787 - accuracy: 0.7160 - val_loss: 2.4487 - val_accuracy: 0.4880
# Epoch 6/40
# 128/128 [==============================] - 203s 2s/step - loss: 0.7464 - accuracy: 0.7616 - val_loss: 2.9021 - val_accuracy: 0.4622
# Epoch 7/40
# 128/128 [==============================] - 201s 2s/step - loss: 0.6261 - accuracy: 0.7976 - val_loss: 1.6297 - val_accuracy: 0.5936
# Epoch 8/40
# 128/128 [==============================] - 201s 2s/step - loss: 0.5113 - accuracy: 0.8406 - val_loss: 2.8782 - val_accuracy: 0.4303
# Epoch 9/40
# 128/128 [==============================] - 202s 2s/step - loss: 0.4158 - accuracy: 0.8607 - val_loss: 2.1881 - val_accuracy: 0.5558
# Epoch 10/40
# 128/128 [==============================] - 220s 2s/step - loss: 0.3274 - accuracy: 0.8989 - val_loss: 1.7209 - val_accuracy: 0.6056
# Epoch 11/40
# 128/128 [==============================] - 218s 2s/step - loss: 0.2507 - accuracy: 0.9249 - val_loss: 1.8308 - val_accuracy: 0.6135
# Epoch 12/40
# 128/128 [==============================] - 204s 2s/step - loss: 0.2297 - accuracy: 0.9291 - val_loss: 2.0979 - val_accuracy: 0.5896
# Epoch 13/40
# 128/128 [==============================] - 212s 2s/step - loss: 0.2097 - accuracy: 0.9365 - val_loss: 2.1079 - val_accuracy: 0.5936
# Epoch 14/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.3206 - accuracy: 0.9139 - val_loss: 2.4756 - val_accuracy: 0.5438
# Epoch 15/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.3537 - accuracy: 0.9004 - val_loss: 1.8973 - val_accuracy: 0.6135
# Epoch 16/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.2058 - accuracy: 0.9409 - val_loss: 1.6406 - val_accuracy: 0.6773
# Epoch 17/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1520 - accuracy: 0.9546 - val_loss: 2.3904 - val_accuracy: 0.5757
# Epoch 18/40
# 128/128 [==============================] - 210s 2s/step - loss: 0.0967 - accuracy: 0.9711 - val_loss: 3.5314 - val_accuracy: 0.4880
# Epoch 19/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1736 - accuracy: 0.9519 - val_loss: 3.1584 - val_accuracy: 0.5000
# Epoch 20/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1730 - accuracy: 0.9475 - val_loss: 3.1385 - val_accuracy: 0.6175
# Epoch 21/40
# 128/128 [==============================] - 208s 2s/step - loss: 0.1791 - accuracy: 0.9534 - val_loss: 2.4025 - val_accuracy: 0.6195
# Epoch 22/40
# 128/128 [==============================] - 210s 2s/step - loss: 0.1877 - accuracy: 0.9534 - val_loss: 5.0640 - val_accuracy: 0.4323
# Epoch 23/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1419 - accuracy: 0.9635 - val_loss: 4.7216 - val_accuracy: 0.4622
# Epoch 24/40
# 128/128 [==============================] - 210s 2s/step - loss: 0.1420 - accuracy: 0.9598 - val_loss: 5.9070 - val_accuracy: 0.4203
# Epoch 25/40
# 128/128 [==============================] - 211s 2s/step - loss: 0.1762 - accuracy: 0.9507 - val_loss: 2.6837 - val_accuracy: 0.5956
# Epoch 26/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.2089 - accuracy: 0.9451 - val_loss: 3.3862 - val_accuracy: 0.5618
# Epoch 27/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1525 - accuracy: 0.9612 - val_loss: 4.5062 - val_accuracy: 0.3825
# Epoch 28/40
# 128/128 [==============================] - 210s 2s/step - loss: 0.1129 - accuracy: 0.9679 - val_loss: 1.9897 - val_accuracy: 0.6594
# Epoch 29/40
# 128/128 [==============================] - 210s 2s/step - loss: 0.1055 - accuracy: 0.9728 - val_loss: 3.4180 - val_accuracy: 0.4761
# Epoch 30/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.0747 - accuracy: 0.9806 - val_loss: 2.4303 - val_accuracy: 0.6554
# Epoch 31/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.0916 - accuracy: 0.9787 - val_loss: 3.1823 - val_accuracy: 0.6016
# Epoch 32/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1712 - accuracy: 0.9654 - val_loss: 3.7944 - val_accuracy: 0.5378
# Epoch 33/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.0999 - accuracy: 0.9750 - val_loss: 3.7571 - val_accuracy: 0.5458
# Epoch 34/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.0862 - accuracy: 0.9767 - val_loss: 3.9008 - val_accuracy: 0.5558
# Epoch 35/40
# 128/128 [==============================] - 208s 2s/step - loss: 0.1107 - accuracy: 0.9733 - val_loss: 5.0314 - val_accuracy: 0.5020
# Epoch 36/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1794 - accuracy: 0.9585 - val_loss: 3.2123 - val_accuracy: 0.5239
# Epoch 37/40
# 128/128 [==============================] - 209s 2s/step - loss: 0.1103 - accuracy: 0.9752 - val_loss: 10.1388 - val_accuracy: 0.3865
# Epoch 38/40
# 128/128 [==============================] - 210s 2s/step - loss: 0.1456 - accuracy: 0.9693 - val_loss: 3.2560 - val_accuracy: 0.5498
# Epoch 39/40
# 128/128 [==============================] - 208s 2s/step - loss: 0.1040 - accuracy: 0.9762 - val_loss: 6.6866 - val_accuracy: 0.4602
# Epoch 40/40
# 128/128 [==============================] - 210s 2s/step - loss: 0.1373 - accuracy: 0.9735 - val_loss: 3.2733 - val_accuracy: 0.5319

# %%
plot_loss_curves(history)

# %%
model.evaluate(test_gen)
# Out:
# 17/17 [==============================] - 15s 941ms/step - loss: 3.1471 - accuracy: 0.5380
# [3.1470892429351807, 0.5380228161811829]

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score
from keras.utils.np_utils import to_categorical
import numpy as np
print("==============TEST RESULTS============")

num_classes = len(train_gen.class_indices)
test_labels = test_gen.classes
test_labels = to_categorical(test_labels, num_classes=num_classes)
y_true = [i.argmax() for i in test_labels]

predictions = model.predict(test_gen, verbose=1)
yPredictions = np.argmax(predictions, axis=1)
true_classes = test_gen.classes
confusion_mtx = confusion_matrix(true_classes, yPredictions) 
y_pred_probabilities=yPredictions
classnames=[]
for classname in test_gen.class_indices:
    classnames.append(classname)

target_names = classnames
print(classification_report(true_classes, yPredictions, target_names=target_names))

# print('roc_auc_score = ' + str(roc_auc_score( true_classes, yPredictions)))
# Out:
# ==============TEST RESULTS============
# 17/17 [==============================] - 11s 650ms/step
#                                      precision    recall  f1-score   support
#
#                Apple Aphis spp(162)       0.67      0.24      0.35        17
#       Apple Eriosoma lanigerum(366)       0.67      0.47      0.55        38
#            Apple Monillia laxa(255)       0.50      0.19      0.28        26
#      Apple Venturia inaequalis(633)       0.88      0.36      0.51        64
# Apricot Coryneum beijerinckii(1101)       0.71      0.72      0.71       111
#           Apricot Monillia laxa(85)       0.67      0.44      0.53         9
#                  Cancer symptom(76)       0.25      0.11      0.15         9
#               Cherry Aphis spp(356)       0.40      0.54      0.46        37
#                   Downy mildew(120)       0.32      1.00      0.49        12
#                 Drying symptom(156)       0.27      0.80      0.40        15
#                       Gray mold(72)       0.57      1.00      0.73         8
#                     Leaf scars(140)       0.47      0.50      0.48        14
#            Peach Monillia laxa(314)       0.41      0.34      0.37        32
#   Peach Parthenolecanium corni(427)       0.93      0.64      0.76        44
#         Pear Erwinia amylovora(215)       0.55      0.55      0.55        22
#                  Plum Aphis spp(70)       0.07      0.14      0.09         7
#                      RoughBark(158)       0.72      0.76      0.74        17
#                   StripeCanker(168)       0.53      0.89      0.67        18
#        Walnut Eriophyes erineus(69)       0.56      0.62      0.59         8
#     Walnut Gnomonia leptostyla(180)       0.14      0.17      0.15        18
#
#                            accuracy                           0.54       526
#                           macro avg       0.51      0.52      0.48       526
#                        weighted avg       0.61      0.54      0.54       526

# %%
sns.heatmap(confusion_mtx.astype("int"), annot=True)
# Out:
# <AxesSubplot:>
